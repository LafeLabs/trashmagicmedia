# %%
import json
f = open("data/sensordata.txt", "r")
textdata = f.read()
data = json.loads(textdata)

# %%
data
# Out:
# [{'Pressure': 841.28, 'Temperature': 24.81, 'timestamp': 1665352775654},
#  {'Pressure': 841.19, 'Temperature': 24.75, 'timestamp': 1665352815748},
#  {'Pressure': 841.12, 'Temperature': 25.12, 'timestamp': 1665354611465},
#  {'Pressure': 840.95, 'Temperature': 25.12, 'timestamp': 1665356876800},
#  {'Pressure': 840.96, 'Temperature': 25.12, 'timestamp': 1665356960342},
#  {'Pressure': 840.94, 'Temperature': 25.12, 'timestamp': 1665357025292},
#  {'Pressure': 840.93, 'Temperature': 25.12, 'timestamp': 1665357090248},
#  {'Pressure': 840.91, 'Temperature': 25.19, 'timestamp': 1665357155202},
#  {'Pressure': 840.94, 'Temperature': 25.19, 'timestamp': 1665357220162},
#  {'Pressure': 840.94, 'Temperature': 25.19, 'timestamp': 1665357285122},
#  {'Pressure': 840.92, 'Temperature': 25.19, 'timestamp': 1665357350075},
#  {'Pressure': 840.91, 'Temperature': 25.19, 'timestamp': 1665357415033},
#  {'Pressure': 840.91, 'Temperature': 25.19, 'timestamp': 1665357479992},
#  {'Pressure': 840.91, 'Temperature': 25.19, 'timestamp': 1665357544945},
#  {'Pressure': 840.92, 'Temperature': 25.19, 'timestamp': 1665357609899},
#  {'Pressure': 840.91, 'Temperature': 25.19, 'timestamp': 1665357674859},
#  {'Pressure': 840.92, 'Temperature': 25.19, 'timestamp': 1665357739801},
#  {'Pressure': 840.92, 'Temperature': 25.12, 'timestamp': 1665357804764},
#  {'Pressure': 840.93, 'Temperature': 25.12, 'timestamp': 1665357869709},
#  {'Pressure': 840.89, 'Temperature': 25.12, 'timestamp': 1665357934651},
#  {'Pressure': 840.92, 'Temperature': 25.12, 'timestamp': 1665357999594},
#  {'Pressure': 840.94, 'Temperature': 25.12, 'timestamp': 1665358064550},
#  {'Pressure': 840.9, 'Temperature': 25.12, 'timestamp': 1665358129504},
#  {'Pressure': 840.91, 'Temperature': 25.12, 'timestamp': 1665358194459},
#  {'Pressure': 840.89, 'Temperature': 25.12, 'timestamp': 1665358259408},
#  {'Pressure': 840.9, 'Temperature': 25.12, 'timestamp': 1665358324356},
#  {'Pressure': 840.92, 'Temperature': 25.12, 'timestamp': 1665358389312},
#  {'Pressure': 840.89, 'Temperature': 25.06, 'timestamp': 1665358454266},
#  {'Pressure': 840.91, 'Temperature': 25.06, 'timestamp': 1665358519209},
#  {'Pressure': 840.9, 'Temperature': 25, 'timestamp': 1665358584167},
#  {'Pressure': 840.91, 'Temperature': 25, 'timestamp': 1665358649123},
#  {'Pressure': 840.87, 'Temperature': 24.94, 'timestamp': 1665358714073},
#  {'Pressure': 840.89, 'Temperature': 24.94, 'timestamp': 1665358779032},
#  {'Pressure': 840.89, 'Temperature': 24.94, 'timestamp': 1665358843987},
#  {'Pressure': 840.95, 'Temperature': 25, 'timestamp': 1665358908950},
#  {'Pressure': 840.91, 'Temperature': 24.94, 'timestamp': 1665358973899},
#  {'Pressure': 840.92, 'Temperature': 24.94, 'timestamp': 1665359038854},
#  {'Pressure': 840.89, 'Temperature': 25, 'timestamp': 1665359103800},
#  {'Pressure': 840.97, 'Temperature': 25, 'timestamp': 1665359168736},
#  {'Pressure': 840.91, 'Temperature': 25, 'timestamp': 1665359233693},
#  {'Pressure': 840.91, 'Temperature': 25, 'timestamp': 1665359298651},
#  {'Pressure': 840.89, 'Temperature': 25, 'timestamp': 1665359363601},
#  {'Pressure': 840.9, 'Temperature': 25, 'timestamp': 1665359428563},
#  {'Pressure': 840.95, 'Temperature': 25.06, 'timestamp': 1665359492467},
#  {'Pressure': 840.94, 'Temperature': 25, 'timestamp': 1665359557416},
#  {'Pressure': 840.92, 'Temperature': 25, 'timestamp': 1665359622372},
#  {'Pressure': 840.95, 'Temperature': 25, 'timestamp': 1665359687323},
#  {'Pressure': 840.96, 'Temperature': 25, 'timestamp': 1665359752276},
#  {'Pressure': 840.97, 'Temperature': 25, 'timestamp': 1665359817241},
#  {'Pressure': 841.02, 'Temperature': 25, 'timestamp': 1665359882190},
#  {'Pressure': 841.02, 'Temperature': 25, 'timestamp': 1665359947145},
#  {'Pressure': 841.03, 'Temperature': 25, 'timestamp': 1665360012100},
#  {'Pressure': 841.03, 'Temperature': 25, 'timestamp': 1665360077043},
#  {'Pressure': 841.05, 'Temperature': 25, 'timestamp': 1665360141995},
#  {'Pressure': 841.04, 'Temperature': 25, 'timestamp': 1665360206956},
#  {'Pressure': 841.05, 'Temperature': 25, 'timestamp': 1665360271892},
#  {'Pressure': 841.12, 'Temperature': 25.06, 'timestamp': 1665360336843},
#  {'Pressure': 841.14, 'Temperature': 24.87, 'timestamp': 1665360401794},
#  {'Pressure': 841.07, 'Temperature': 25, 'timestamp': 1665360466741},
#  {'Pressure': 841.15, 'Temperature': 24.87, 'timestamp': 1665360531688},
#  {'Pressure': 841.14, 'Temperature': 24.81, 'timestamp': 1665360596632},
#  {'Pressure': 841.07, 'Temperature': 25, 'timestamp': 1665360661584},
#  {'Pressure': 841.09, 'Temperature': 25, 'timestamp': 1665360726521},
#  {'Pressure': 841.15, 'Temperature': 24.81, 'timestamp': 1665360791470},
#  {'Pressure': 841.1, 'Temperature': 24.94, 'timestamp': 1665360856423},
#  {'Pressure': 841.12, 'Temperature': 24.75, 'timestamp': 1665360921366},
#  {'Pressure': 841.15, 'Temperature': 24.75, 'timestamp': 1665360986319},
#  {'Pressure': 841.11, 'Temperature': 24.69, 'timestamp': 1665361051258},
#  {'Pressure': 841.15, 'Temperature': 24.69, 'timestamp': 1665361116216},
#  {'Pressure': 841.11, 'Temperature': 24.62, 'timestamp': 1665361181157},
#  {'Pressure': 841.16, 'Temperature': 24.62, 'timestamp': 1665361246093},
#  {'Pressure': 841.21, 'Temperature': 24.62, 'timestamp': 1665361311042},
#  {'Pressure': 841.19, 'Temperature': 24.62, 'timestamp': 1665361375994},
#  {'Pressure': 841.22, 'Temperature': 24.56, 'timestamp': 1665361440934},
#  {'Pressure': 841.2, 'Temperature': 24.56, 'timestamp': 1665361505887},
#  {'Pressure': 841.2, 'Temperature': 24.5, 'timestamp': 1665361570853},
#  {'Pressure': 841.23, 'Temperature': 24.5, 'timestamp': 1665361635803},
#  {'Pressure': 841.33, 'Temperature': 24.56, 'timestamp': 1665361700742},
#  {'Pressure': 841.28, 'Temperature': 24.5, 'timestamp': 1665361765697},
#  {'Pressure': 841.36, 'Temperature': 24.5, 'timestamp': 1665361830643},
#  {'Pressure': 841.32, 'Temperature': 24.5, 'timestamp': 1665361895623},
#  {'Pressure': 841.36, 'Temperature': 24.5, 'timestamp': 1665361960561},
#  {'Pressure': 841.36, 'Temperature': 24.44, 'timestamp': 1665362025511},
#  {'Pressure': 841.35, 'Temperature': 24.44, 'timestamp': 1665362090472},
#  {'Pressure': 841.34, 'Temperature': 24.44, 'timestamp': 1665362155432},
#  {'Pressure': 841.32, 'Temperature': 24.37, 'timestamp': 1665362220379},
#  {'Pressure': 841.34, 'Temperature': 24.37, 'timestamp': 1665362285336},
#  {'Pressure': 841.35, 'Temperature': 24.37, 'timestamp': 1665362350283},
#  {'Pressure': 841.34, 'Temperature': 24.37, 'timestamp': 1665362415227},
#  {'Pressure': 841.34, 'Temperature': 24.37, 'timestamp': 1665362480173},
#  {'Pressure': 841.38, 'Temperature': 24.37, 'timestamp': 1665362545131},
#  {'Pressure': 841.37, 'Temperature': 24.31, 'timestamp': 1665362610086},
#  {'Pressure': 841.38, 'Temperature': 24.31, 'timestamp': 1665362675051},
#  {'Pressure': 841.37, 'Temperature': 24.31, 'timestamp': 1665362740001},
#  {'Pressure': 841.4, 'Temperature': 24.25, 'timestamp': 1665362804958},
#  {'Pressure': 841.38, 'Temperature': 24.25, 'timestamp': 1665362869914},
#  {'Pressure': 841.41, 'Temperature': 24.25, 'timestamp': 1665362934858},
#  {'Pressure': 841.42, 'Temperature': 24.25, 'timestamp': 1665362999807},
#  {'Pressure': 841.4, 'Temperature': 24.25, 'timestamp': 1665363064757},
#  {'Pressure': 841.44, 'Temperature': 24.25, 'timestamp': 1665363129716},
#  {'Pressure': 841.42, 'Temperature': 24.19, 'timestamp': 1665363194678},
#  {'Pressure': 841.43, 'Temperature': 24.19, 'timestamp': 1665363259633},
#  {'Pressure': 841.44, 'Temperature': 24.19, 'timestamp': 1665363324584},
#  {'Pressure': 841.42, 'Temperature': 24.19, 'timestamp': 1665363389542},
#  {'Pressure': 841.41, 'Temperature': 24.12, 'timestamp': 1665363454497},
#  {'Pressure': 841.5, 'Temperature': 24.19, 'timestamp': 1665363519446},
#  {'Pressure': 841.46, 'Temperature': 24.19, 'timestamp': 1665363584396},
#  {'Pressure': 841.44, 'Temperature': 24.12, 'timestamp': 1665363649355},
#  {'Pressure': 841.47, 'Temperature': 24.19, 'timestamp': 1665363714304},
#  {'Pressure': 841.46, 'Temperature': 24.12, 'timestamp': 1665363779262},
#  {'Pressure': 841.49, 'Temperature': 24.19, 'timestamp': 1665363844209},
#  {'Pressure': 841.46, 'Temperature': 24.12, 'timestamp': 1665363909154},
#  {'Pressure': 841.47, 'Temperature': 24.19, 'timestamp': 1665363974111},
#  {'Pressure': 841.47, 'Temperature': 24.19, 'timestamp': 1665364039058}]

# %%
import matplotlib.pyplot as plt
import numpy as np
pressurewave = []
temperaturewave = []
timewave = []
for x in data:
    #print(x['Pressure'])
    pressurewave.append(x['Pressure'])
    temperaturewave.append(x['Temperature'])
    timewave.append(x['timestamp'])
plt.plot(timewave,pressurewave)

# %%
plt.plot(pressurewave)

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c9d8a7245e33> in <module>
# ----> 1 xpoints.push(2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'push'
