# %%
import json
f = open("data/sensordata.txt", "r")
textdata = f.read()
data = json.loads(textdata)

# %%
data
# Out:
# [{'Pressure': 837.53, 'Temperature': 23.87, 'timestamp': 1665424997094},
#  {'Pressure': 837.55, 'Temperature': 24, 'timestamp': 1665425062083},
#  {'Pressure': 837.47, 'Temperature': 24, 'timestamp': 1665425127071},
#  {'Pressure': 837.59, 'Temperature': 23.94, 'timestamp': 1665425192061},
#  {'Pressure': 837.45, 'Temperature': 24.06, 'timestamp': 1665425256997},
#  {'Pressure': 837.27, 'Temperature': 24, 'timestamp': 1665425321503},
#  {'Pressure': 837.43, 'Temperature': 24.06, 'timestamp': 1665425386466},
#  {'Pressure': 836.51, 'Temperature': 23.62, 'timestamp': 1665425451460},
#  {'Pressure': 836.63, 'Temperature': 23, 'timestamp': 1665425516449},
#  {'Pressure': 836.5, 'Temperature': 24, 'timestamp': 1665425581437},
#  {'Pressure': 836.59, 'Temperature': 23.19, 'timestamp': 1665425646427},
#  {'Pressure': 836.79, 'Temperature': 22.31, 'timestamp': 1665425711416},
#  {'Pressure': 836.9, 'Temperature': 20.81, 'timestamp': 1665425776402},
#  {'Pressure': 836.69, 'Temperature': 21.5, 'timestamp': 1665425841377},
#  {'Pressure': 836.87, 'Temperature': 21.87, 'timestamp': 1665425906327},
#  {'Pressure': 836.9, 'Temperature': 21.06, 'timestamp': 1665425971316},
#  {'Pressure': 836.8, 'Temperature': 23.44, 'timestamp': 1665426036308},
#  {'Pressure': 836.77, 'Temperature': 21.19, 'timestamp': 1665426101299},
#  {'Pressure': 836.75, 'Temperature': 21.06, 'timestamp': 1665426166289},
#  {'Pressure': 836.5, 'Temperature': 21.62, 'timestamp': 1665426231281},
#  {'Pressure': 836.58, 'Temperature': 21.25, 'timestamp': 1665426296277},
#  {'Pressure': 836.19, 'Temperature': 22.75, 'timestamp': 1665426361268},
#  {'Pressure': 836.49, 'Temperature': 21.94, 'timestamp': 1665426425776},
#  {'Pressure': 836.6, 'Temperature': 21.5, 'timestamp': 1665426490767},
#  {'Pressure': 836.2, 'Temperature': 22.31, 'timestamp': 1665426555726},
#  {'Pressure': 836.31, 'Temperature': 23.19, 'timestamp': 1665426620713},
#  {'Pressure': 836.28, 'Temperature': 23.5, 'timestamp': 1665426685702},
#  {'Pressure': 836.19, 'Temperature': 23.56, 'timestamp': 1665426750692},
#  {'Pressure': 836.22, 'Temperature': 24, 'timestamp': 1665426815682},
#  {'Pressure': 836.25, 'Temperature': 24.06, 'timestamp': 1665426880672},
#  {'Pressure': 836.19, 'Temperature': 23.81, 'timestamp': 1665426945662},
#  {'Pressure': 836.27, 'Temperature': 24.19, 'timestamp': 1665427010652},
#  {'Pressure': 836.21, 'Temperature': 24.56, 'timestamp': 1665427075607},
#  {'Pressure': 836.36, 'Temperature': 24.69, 'timestamp': 1665427267828},
#  {'Pressure': 836.19, 'Temperature': 24.87, 'timestamp': 1665427332790},
#  {'Pressure': 836.16, 'Temperature': 25.25, 'timestamp': 1665427397771},
#  {'Pressure': 836.04, 'Temperature': 26.12, 'timestamp': 1665427462756},
#  {'Pressure': 837.34, 'Temperature': 33.94, 'timestamp': 1665427527737},
#  {'Pressure': 836.64, 'Temperature': 29.37, 'timestamp': 1665427592746},
#  {'Pressure': 838.3, 'Temperature': 38.56, 'timestamp': 1665427658169},
#  {'Pressure': 837.35, 'Temperature': 34.06, 'timestamp': 1665427724174},
#  {'Pressure': 837.98, 'Temperature': 36.19, 'timestamp': 1665427790663},
#  {'Pressure': 838.26, 'Temperature': 39.75, 'timestamp': 1665427856467},
#  {'Pressure': 838.38, 'Temperature': 41.38, 'timestamp': 1665427922907},
#  {'Pressure': 838.46, 'Temperature': 42.31, 'timestamp': 1665427989161},
#  {'Pressure': 838.84, 'Temperature': 44.38, 'timestamp': 1665428055207},
#  {'Pressure': 838.71, 'Temperature': 43.75, 'timestamp': 1665428121741},
#  {'Pressure': 838.73, 'Temperature': 46.25, 'timestamp': 1665428188289},
#  {'Pressure': 838.65, 'Temperature': 44.5, 'timestamp': 1665428254073},
#  {'Pressure': 838.51, 'Temperature': 45.75, 'timestamp': 1665428319896},
#  {'Pressure': 838.78, 'Temperature': 45.38, 'timestamp': 1665428385779},
#  {'Pressure': 838.67, 'Temperature': 46.69, 'timestamp': 1665428451738},
#  {'Pressure': 838.7, 'Temperature': 47.69, 'timestamp': 1665428518384},
#  {'Pressure': 838.59, 'Temperature': 47.63, 'timestamp': 1665428585415},
#  {'Pressure': 838.41, 'Temperature': 48.19, 'timestamp': 1665428651519},
#  {'Pressure': 838.13, 'Temperature': 47.88, 'timestamp': 1665428717874},
#  {'Pressure': 838.53, 'Temperature': 47.81, 'timestamp': 1665428783791},
#  {'Pressure': 838.45, 'Temperature': 48.69, 'timestamp': 1665428849985},
#  {'Pressure': 838.41, 'Temperature': 48, 'timestamp': 1665428916268},
#  {'Pressure': 838.32, 'Temperature': 48.5, 'timestamp': 1665428982307},
#  {'Pressure': 838.17, 'Temperature': 48.44, 'timestamp': 1665429047476},
#  {'Pressure': 838.05, 'Temperature': 47.63, 'timestamp': 1665429112861},
#  {'Pressure': 837.98, 'Temperature': 48.38, 'timestamp': 1665429178058},
#  {'Pressure': 837.85, 'Temperature': 48, 'timestamp': 1665429243242},
#  {'Pressure': 837.88, 'Temperature': 48.25, 'timestamp': 1665429308392},
#  {'Pressure': 837.99, 'Temperature': 47.94, 'timestamp': 1665429373507},
#  {'Pressure': 837.86, 'Temperature': 47.63, 'timestamp': 1665429438482},
#  {'Pressure': 837.81, 'Temperature': 47.38, 'timestamp': 1665429503437},
#  {'Pressure': 837.83, 'Temperature': 48, 'timestamp': 1665429568417},
#  {'Pressure': 837.49, 'Temperature': 48.69, 'timestamp': 1665429633408},
#  {'Pressure': 837.6, 'Temperature': 49.38, 'timestamp': 1665429698367},
#  {'Pressure': 837.83, 'Temperature': 49.19, 'timestamp': 1665429763337},
#  {'Pressure': 837.76, 'Temperature': 49.69, 'timestamp': 1665429828326},
#  {'Pressure': 837.25, 'Temperature': 48.63, 'timestamp': 1665429893268},
#  {'Pressure': 837.27, 'Temperature': 48.75, 'timestamp': 1665429958258},
#  {'Pressure': 837.44, 'Temperature': 49.19, 'timestamp': 1665430023197},
#  {'Pressure': 836.91, 'Temperature': 42.81, 'timestamp': 1665430088133},
#  {'Pressure': 836.95, 'Temperature': 43.06, 'timestamp': 1665430153112},
#  {'Pressure': 837.2, 'Temperature': 47.5, 'timestamp': 1665430218067},
#  {'Pressure': 837.16, 'Temperature': 44.5, 'timestamp': 1665430283060},
#  {'Pressure': 836.8, 'Temperature': 44.63, 'timestamp': 1665430348048},
#  {'Pressure': 836.41, 'Temperature': 39.31, 'timestamp': 1665430413034},
#  {'Pressure': 836.58, 'Temperature': 39.38, 'timestamp': 1665430478022},
#  {'Pressure': 836.55, 'Temperature': 36.81, 'timestamp': 1665430542964},
#  {'Pressure': 836.33, 'Temperature': 33.13, 'timestamp': 1665430607927},
#  {'Pressure': 836.62, 'Temperature': 36.38, 'timestamp': 1665430672918},
#  {'Pressure': 836.47, 'Temperature': 32.88, 'timestamp': 1665430737911},
#  {'Pressure': 836.34, 'Temperature': 34.81, 'timestamp': 1665430802915},
#  {'Pressure': 836.42, 'Temperature': 32.5, 'timestamp': 1665430868026},
#  {'Pressure': 836.98, 'Temperature': 37.44, 'timestamp': 1665430932972},
#  {'Pressure': 836.79, 'Temperature': 40.25, 'timestamp': 1665430997960},
#  {'Pressure': 836.2, 'Temperature': 32.81, 'timestamp': 1665431062996},
#  {'Pressure': 836.48, 'Temperature': 37.94, 'timestamp': 1665431127453},
#  {'Pressure': 836.17, 'Temperature': 34.06, 'timestamp': 1665431192443},
#  {'Pressure': 836.09, 'Temperature': 35.13, 'timestamp': 1665431257398},
#  {'Pressure': 836.11, 'Temperature': 31.94, 'timestamp': 1665431322377},
#  {'Pressure': 836.08, 'Temperature': 31, 'timestamp': 1665431387347},
#  {'Pressure': 835.97, 'Temperature': 30.37, 'timestamp': 1665431452338},
#  {'Pressure': 836.34, 'Temperature': 34.81, 'timestamp': 1665431517328},
#  {'Pressure': 836.04, 'Temperature': 30.12, 'timestamp': 1665431582321},
#  {'Pressure': 836.24, 'Temperature': 32, 'timestamp': 1665431647311},
#  {'Pressure': 836.09, 'Temperature': 33.38, 'timestamp': 1665431712276},
#  {'Pressure': 836.15, 'Temperature': 33, 'timestamp': 1665431777241},
#  {'Pressure': 836.03, 'Temperature': 32, 'timestamp': 1665431842210},
#  {'Pressure': 836.54, 'Temperature': 37.25, 'timestamp': 1665431907201},
#  {'Pressure': 836.19, 'Temperature': 35.56, 'timestamp': 1665431972185},
#  {'Pressure': 836.32, 'Temperature': 39.75, 'timestamp': 1665432037117},
#  {'Pressure': 836.27, 'Temperature': 36.56, 'timestamp': 1665432102083},
#  {'Pressure': 836.29, 'Temperature': 38.75, 'timestamp': 1665432167072},
#  {'Pressure': 836.25, 'Temperature': 36.31, 'timestamp': 1665432232030},
#  {'Pressure': 836.39, 'Temperature': 41.81, 'timestamp': 1665432296990},
#  {'Pressure': 836.4, 'Temperature': 42.06, 'timestamp': 1665432361980},
#  {'Pressure': 835.92, 'Temperature': 36.5, 'timestamp': 1665432426907},
#  {'Pressure': 835.88, 'Temperature': 33.38, 'timestamp': 1665432491890},
#  {'Pressure': 836.09, 'Temperature': 40.06, 'timestamp': 1665432556848},
#  {'Pressure': 836.12, 'Temperature': 35.13, 'timestamp': 1665432621835},
#  {'Pressure': 835.79, 'Temperature': 34.56, 'timestamp': 1665432686831},
#  {'Pressure': 836.31, 'Temperature': 36.38, 'timestamp': 1665432751765},
#  {'Pressure': 836.36, 'Temperature': 40.19, 'timestamp': 1665432816696},
#  {'Pressure': 836.42, 'Temperature': 39.25, 'timestamp': 1665432881703},
#  {'Pressure': 835.87, 'Temperature': 35.5, 'timestamp': 1665432946630},
#  {'Pressure': 836.13, 'Temperature': 39.06, 'timestamp': 1665433011607},
#  {'Pressure': 835.66, 'Temperature': 32.31, 'timestamp': 1665433076660},
#  {'Pressure': 835.43, 'Temperature': 31.12, 'timestamp': 1665433141811},
#  {'Pressure': 835.59, 'Temperature': 33.44, 'timestamp': 1665433206982},
#  {'Pressure': 835.51, 'Temperature': 30.19, 'timestamp': 1665433271973},
#  {'Pressure': 836, 'Temperature': 38.38, 'timestamp': 1665433336954},
#  {'Pressure': 835.51, 'Temperature': 29.62, 'timestamp': 1665433401901},
#  {'Pressure': 835.59, 'Temperature': 29.5, 'timestamp': 1665433466904},
#  {'Pressure': 835.68, 'Temperature': 30.44, 'timestamp': 1665433531845},
#  {'Pressure': 835.95, 'Temperature': 32.06, 'timestamp': 1665433596835},
#  {'Pressure': 835.89, 'Temperature': 35, 'timestamp': 1665433661791},
#  {'Pressure': 835.89, 'Temperature': 33.69, 'timestamp': 1665433726794},
#  {'Pressure': 835.8, 'Temperature': 35.63, 'timestamp': 1665433791287},
#  {'Pressure': 835.75, 'Temperature': 35.81, 'timestamp': 1665433856279},
#  {'Pressure': 835.77, 'Temperature': 36.69, 'timestamp': 1665433921270},
#  {'Pressure': 835.58, 'Temperature': 37.31, 'timestamp': 1665433986227},
#  {'Pressure': 835.6, 'Temperature': 36.81, 'timestamp': 1665434051221},
#  {'Pressure': 835.77, 'Temperature': 37.19, 'timestamp': 1665434116214},
#  {'Pressure': 835.52, 'Temperature': 36.88, 'timestamp': 1665434181207},
#  {'Pressure': 835.4, 'Temperature': 38.19, 'timestamp': 1665434246167},
#  {'Pressure': 835.41, 'Temperature': 37.81, 'timestamp': 1665434311100},
#  {'Pressure': 835.4, 'Temperature': 38.56, 'timestamp': 1665434376047},
#  {'Pressure': 835.13, 'Temperature': 38.81, 'timestamp': 1665434441097},
#  {'Pressure': 835.22, 'Temperature': 38.94, 'timestamp': 1665434506286},
#  {'Pressure': 835.09, 'Temperature': 38.75, 'timestamp': 1665434571484},
#  {'Pressure': 835.03, 'Temperature': 38.06, 'timestamp': 1665434636689},
#  {'Pressure': 835.23, 'Temperature': 38.44, 'timestamp': 1665434701830},
#  {'Pressure': 835.09, 'Temperature': 38.81, 'timestamp': 1665434766969},
#  {'Pressure': 835.26, 'Temperature': 38.31, 'timestamp': 1665434832165},
#  {'Pressure': 834.91, 'Temperature': 39.19, 'timestamp': 1665434897381},
#  {'Pressure': 834.87, 'Temperature': 38.75, 'timestamp': 1665434963037},
#  {'Pressure': 834.96, 'Temperature': 39, 'timestamp': 1665435028203},
#  {'Pressure': 835.01, 'Temperature': 38.56, 'timestamp': 1665435093392},
#  {'Pressure': 834.87, 'Temperature': 38.56, 'timestamp': 1665435158579},
#  {'Pressure': 834.89, 'Temperature': 38, 'timestamp': 1665435223967},
#  {'Pressure': 834.88, 'Temperature': 38.81, 'timestamp': 1665435289084}]

# %%
import matplotlib.pyplot as plt
import numpy as np
pressurewave = []
temperaturewave = []
fwave = []
minwave = []
timewave = []
for x in data:
    #print(x['Pressure'])
    pressurewave.append(x['Pressure'])
    temperaturewave.append(x['Temperature'])
    fwave.append(32.0 + x['Temperature']*9/5)
    timewave.append(x['timestamp'])
    minwave.append((x['timestamp'] - data[0]['timestamp'])/60000)
plt.plot(minwave,fwave)

# %%
plt.plot(minwave,pressurewave)

# %%
plt.plot(fwave,pressurewave,"r+")

# %%
fig = plt.figure(tight_layout=True)
ax = fig.add_subplot()
ax.plot(minwave,fwave)
ax.set_ylabel('Temperature[F]')
ax.set_xlabel('time[minutes]')
# Out:
# Text(0.5, 0, 'time[minutes]')

# %%
fig = plt.figure(tight_layout=True)
ax = fig.add_subplot()
ax.plot(pressurewave,fwave,'r+')
ax.set_ylabel('Temperature[F]')
ax.set_xlabel('Pressure[hPa]')
# Out:
# Text(0.5, 0, 'Pressure[hPa]')

# %%
data[0]['timestamp']
# Out:
# 1665424997094
